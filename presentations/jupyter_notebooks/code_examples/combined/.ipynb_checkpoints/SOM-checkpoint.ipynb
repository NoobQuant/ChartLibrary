# %% [markdown]
# ## Self-organizing map (SOM) example in Python (with R magic)
# This notebook is a small demonstration on how to use R commands in a Jupyter notebook running a Python kernel. Example is based on an excellent <a href="https://www.shanelynn.ie/self-organising-maps-for-customer-segmentation-using-r/">article</a> by Shane Lynn where and deals with customer segmentation in Dublin, Ireland.
#
# R commands are given in cells with magic R line "%%R"on the first line of the cell.

# %%
# Dependencies
# %matplotlib notebook
import matplotlib.pyplot as plt
import rpy2
import numpy as np
import pandas as pd
import seaborn as sns
# %load_ext rpy2.ipython

# %% [markdown]
# Instal R package "kohonen" if haven't already.

# %%
#%%R
#install.packages("kohonen", repos='http://cran.us.r-project.org')

# %% [markdown]
# Load package into memory.

# %%
# %%R
# require(kohonen)

# %% [markdown]
# ## Load prepared data
# Data exhibits statistics from different regions in greater Dublin area.

# %%
data = pd.read_csv("prepared_data.csv")
del data['Unnamed: 0']

# %% [markdown]
# Display first observations and descriptive statistics using Python.

# %%
data.head()
# Out:
#           id    avr_age  avr_household_size  avr_education_level  \
# 0  267123023  40.028112            2.524752             3.038462
# 1  267016001  35.673660            3.320611             3.597701
# 2  267016002  35.882353            3.324324             4.295302
# 3  267002034  38.516667            3.088608             3.871795
# 4  267002029  24.678005            3.512000             3.933735
#
#    avr_num_cars  avr_health  rented_percent  unemployment_percent  \
# 0      1.039604    4.385542        6.930693             15.343915
# 1      1.983740    4.509434        4.878049             12.461059
# 2      1.905405    4.596639        1.351351             10.404624
# 3      1.730769    4.530172        3.896104              8.108108
# 4      1.112000    4.510345       20.800000             21.810700
#
#    internet_percent  single_percent  married_percent  separated_percent  \
# 0         71.000000       53.413655        33.333333           4.819277
# ...

# %%
data.describe()
# Out:
#            avr_age  avr_household_size  avr_education_level  avr_num_cars  \
# count  4046.000000         4046.000000          4046.000000   4046.000000
# mean     35.192782            2.629909             4.547223      1.103039
# std       6.788398            0.524814             1.408368      0.440469
# min      19.029703            1.017544             1.570093      0.035088
# 25%      29.743432            2.259761             3.403555      0.795017
# 50%      35.434853            2.620530             4.588074      1.109233
# 75%      39.882333            2.992028             5.566059      1.446939
# max      72.548780            4.660377             9.000000      2.281250
#
#         avr_health  rented_percent  unemployment_percent  internet_percent  \
# count  4046.000000     4046.000000           4046.000000       4046.000000
# mean      4.496449       27.305119             12.450245         78.905046
# std       0.156291       24.556180              7.618177         13.146915
# ...

# %% [markdown]
# ## Plot data in Python

# %%
def scatter3D(df,**kwargs):
    """
    Function to plot 3D scatter plot.
    Takes as innput a pandas data frame
    with shape (x, 3).
    
    Notes:
     - requires matplotlib to be imported as
       import matplotlib.pyplot as plt
    
    Versioning
    - 0.1 by Ville Voutilainen
        Initial build
    """
    from mpl_toolkits.mplot3d import Axes3D
    if df.shape[1] != 3:
        raise ValueError('Data frame does not have three columns.')
    
    figsize       = kwargs.get('figsize',(9,5))
    edgecolor     = kwargs.get('edgecolor','k')
    scatter_s     = kwargs.get('scatter_s', 40)
    title         = kwargs.get('title', None)
    xlabel        = kwargs.get('xlabel', df.columns[0])
    ylabel        = kwargs.get('ylabel', df.columns[1])
    zlabel        = kwargs.get('zlabel', df.columns[2])
    azim          = kwargs.get('azim', 0)
    elev          = kwargs.get('elev', 20)
    xlim = kwargs.get('xlim',None)
    ylim = kwargs.get('ylim',None)
    zlim = kwargs.get('zlim',None)    
    return_plot   = kwargs.get('return_plot', True)    

    ###################################
    # Core plot
    ###################################        
    fig = plt.figure(figsize=figsize)        
    ax = fig.add_subplot(1, 1, 1, projection='3d')
    ax.scatter(df.iloc[:, 0], df.iloc[:, 1], df.iloc[:, 2], 
               edgecolor = edgecolor, s=scatter_s)    
    ax.view_init(azim = azim, elev = elev)
    
    ###################################
    # Stylings
    ###################################
    if title is not None:
        ax.set_title(title)    
    if xlabel != 'none':
        ax.set_xlabel(xlabel)
    if ylabel != 'none':
        ax.set_ylabel(ylabel)
    if zlabel != 'none':
        ax.set_zlabel(zlabel)
    if xlim != None:
        ax.set_xlim(xlim)
    if ylim != None:
        ax.set_ylim(ylim)
    if zlim != None:
        ax.set_zlim(zlim)
        
    ###################################
    # Return
    ###################################    
    if return_plot == True:
        return fig, ax

# %%
# 3D scatter plot
df_plot = data[['avr_age', 'avr_education_level','unemployment_percent']]
scatter3D(df_plot, return_plot = False, figsize=(10,7))
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# There is definitely something going on with eduacation level and unemployment. Let's see that once more in 2 dimensions. Plot a scatter with seaborn where dots are grouped into hexagonal areas. Seems that eduaction level and unemployment are inversely related.

# %%
grid2 = sns.jointplot(df_plot.loc[:,'avr_education_level'],df_plot.loc[:,'unemployment_percent'],
                      alpha = 0.8, kind = 'hex', size = 7)
# Out:
# <img src="data:image/png;base64,..." width="699.5555555555555">
# C:\Users\ville_000\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Train SOM

# %%
# Select data for SOM
df_train = data[['avr_age','avr_education_level','avr_num_cars','unemployment_percent']]

# %% [markdown]
# Train SOM in R! We import Python pandas data frame df_train into R instance by R macig command <i>-i</i>.Trained model som_model is stored in memory for later R instances. We can also export data from R back to Python with command <i>-o</i>, as we do for data frame export_df.

# %%
# %%R -i df_train -o export_df
#
# data_train = df_train
# # Scale and center all columns
# data_train_matrix = as.matrix(scale(data_train))
# names(data_train_matrix) = names(data_train)
#
# # larger grid for the small areas example (more samples)
# som_grid = somgrid(xdim = 20, ydim=20, topo="hexagonal")
#
# # Train the SOM model
# som_model = som(data_train_matrix,
#                 grid=som_grid,
#                 rlen=500,
#                 alpha=c(0.1,0.01),
#                 keep.data = TRUE )
#
# export_df = as.data.frame(data_train_matrix)

# %%
# Display again in Python
pd.DataFrame(export_df).head()
# Out:
#     avr_age  avr_education_level  avr_num_cars  unemployment_percent
# 0  0.712293            -1.071283     -0.144017              0.379838
# 1  0.070838            -0.674200      1.999464              0.001420
# 2  0.101581            -0.178874      1.821621             -0.268518
# 3  0.489642            -0.479582      1.425143             -0.569971
# 4 -1.548933            -0.435602      0.020345              1.228700

# %% [markdown]
# Node counts: How many samples are mapped to each node on the map?
# Notice how plot dimensions are passed into R cell in the first R magic line!

# %%
# %%R -w 640 -h 640 -u px
# source('coolBlueHotRed.R')
# plot(som_model, type = "counts", main="Node Counts", palette.name=coolBlueHotRed)

# %% [markdown]
# Heatmaps per variable, in original units. Won't work if some node is empty! Source provides an attemp to correct this but the code does not work

# %%
# %%R -w 640 -h 640 -u px -o var_unscaled
# # Plot the heat map with original data scale. Essentially we take the mean of the
# # variable values of each observations in a given node
# var = 3
# var_unscaled = aggregate(as.numeric(data_train[,var]), by=list(som_model$unit.classif), FUN=mean, simplify=TRUE)[,2]
# plot(som_model, type = "property", property=var_unscaled, main=names(data_train)[var], palette.name=coolBlueHotRed)
